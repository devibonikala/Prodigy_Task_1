# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/home/rguktong/Desktop/2101e6d6-1ebe-47fc-bb17-9d64aff35ed8_Data.csv')
data=df.iloc[14]
print(data)
plt.figure(figsize=(25, 10))
plt.hist(data, bins=30, edgecolor='black', alpha=0.7)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Example Data')
plt.show()
# Out:
# Series Name      Ratio of female to male labor force participat...
# Series Code                                      SL.TLF.CACT.FM.ZS
# Country Name                                               Bahrain
# Country Code                                                   BHR
# 2014 [YR2014]                                     49.7609981365956
# 2015 [YR2015]                                     49.9419670837299
# 2016 [YR2016]                                     50.0416801741305
# 2017 [YR2017]                                     50.2156713491569
# 2018 [YR2018]                                     50.6092588977065
# 2019 [YR2019]                                     50.8466026985819
# 2020 [YR2020]                                     50.4220779220779
# 2021 [YR2021]                                     50.4254852379138
# 2022 [YR2022]                                     50.3530789633831
# 2023 [YR2023]                                     50.6693148420279
# Name: 14, dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt 
df=pd.read_csv('/home/rguktong/Desktop/2101e6d6-1ebe-47fc-bb17-9d64aff35ed8_Data.csv')

gender=df.iloc[15]   #selects as 1st row
population = df.iloc[15]

# Create the bar chart as shown in the previous example
plt.figure(figsize=(20, 15))  # Adjust figure size if needed
plt.bar(gender, population, color='green')

plt.xlabel('Age Groups')
plt.ylabel('Population')
plt.title('Population Distribution by Age Groups')
# Out:
# Text(0.5, 1.0, 'Population Distribution by Age Groups')

# %%
import pandas as pd
import matplotlib.pyplot as plt 
df=pd.read_csv('/home/rguktong/Desktop/2101e6d6-1ebe-47fc-bb17-9d64aff35ed8_Data.csv')
d
# Out:
#                                            Series Name        Series Code  \
# 0    Ratio of female to male labor force participat...  SL.TLF.CACT.FM.ZS
# 1    Ratio of female to male labor force participat...  SL.TLF.CACT.FM.ZS
# 2    Ratio of female to male labor force participat...  SL.TLF.CACT.FM.ZS
# 3    Ratio of female to male labor force participat...  SL.TLF.CACT.FM.ZS
# 4    Ratio of female to male labor force participat...  SL.TLF.CACT.FM.ZS
# ..                                                 ...                ...
# 217                                                NaN                NaN
# 218                                                NaN                NaN
# 219                                                NaN                NaN
# 220              Data from database: Gender Statistics                NaN
# 221                           Last Updated: 07/01/2024                NaN
#
#        Country Name Country Code     2014 [YR2014]     2015 [YR2015]  \
# 0       Afghanistan          AFG  23.7490645063876  25.3757325289357
# 1           Albania          ALB  69.4344525963839  73.3286516853933
# 2           Algeria          DZA  22.5044102439321  24.3894717800289
# 3    American Samoa          ASM                ..                ..
# 4           Andorra          AND                ..                ..
# ..              ...          ...               ...               ...
# 217             NaN          NaN               NaN               NaN
# 218             NaN          NaN               NaN               NaN
# 219             NaN          NaN               NaN               NaN
# 220             NaN          NaN               NaN               NaN
# 221             NaN          NaN               NaN               NaN
#
#         2016 [YR2016]     2017 [YR2017]     2018 [YR2018]     2019 [YR2019]  \
# 0    27.1029295008949    28.93696493811  27.8325779792055  26.5817299358641
# 1    76.6610694313928  74.5193174307517  76.1195137517997  77.8305014810121
# 2     25.479655344731  25.2633331315455  25.0453720508167  24.8565041387227
# 3                  ..                ..                ..                ..
# 4                  ..                ..                ..                ..
# ..                ...               ...               ...               ...
# 217               NaN               NaN               NaN               NaN
# 218               NaN               NaN               NaN               NaN
# 219               NaN               NaN               NaN               NaN
# 220               NaN               NaN               NaN               NaN
# 221               NaN               NaN               NaN               NaN
#
#         2020 [YR2020]     2021 [YR2021]     2022 [YR2022]     2023 [YR2023]
# 0    24.6862301129122  21.8409819358079  7.34537368323521  6.98535794895538
# 1    77.4244906791974  78.7746037540689  78.0343581803436  78.0831029844348
# 2    24.6660915132924  25.4346927747227  24.5996387718242    25.09815044261
# 3                  ..                ..                ..                ..
# 4                  ..                ..                ..                ..
# ..                ...               ...               ...               ...
# 217               NaN               NaN               NaN               NaN
# 218               NaN               NaN               NaN               NaN
# 219               NaN               NaN               NaN               NaN
# 220               NaN               NaN               NaN               NaN
# 221               NaN               NaN               NaN               NaN
#
# [222 rows x 14 columns]
